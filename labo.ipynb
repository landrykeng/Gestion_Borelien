# %%
import gspread
import pandas as pd
from google.oauth2.service_account import Credentials
SERVICE_ACCOUNT_FILE = "Credential.json"

# %%
# Scopes nécessaires (Sheets + Drive)
SCOPES = ["https://www.googleapis.com/auth/spreadsheets",
          "https://www.googleapis.com/auth/drive"]

# Authentification
creds = Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
client = gspread.authorize(creds)

# Ouvre le Google Sheet (par nom ou par URL)
sheet = client.open("Data_Gestion") # feuille 1

# %%
# Sélectionner la première feuille
worksheet = sheet.worksheet("Séances")

# Récupérer toutes les données
data = worksheet.get_all_records()  # retourne une liste de dicts

# Convertir en DataFrame
df = pd.DataFrame(data)

# %%
from Fonction import *
# Out:
# 2025-08-25 17:39:23.105 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-25 17:39:23.826
# ...
#   command:
#
#     streamlit run C:\Users\LK\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-08-25 17:39:23.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df=read_from_google_sheet("Enseignants")
# Out:
# 2025-08-25 17:52:33.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-25 17:52:33.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df
# Out:
#     ID         Nom    Prénom           Matière     Téléphone Statut
# 0    1    BASKOUDA    Gérard          Français                   PA
# 1    2     BESSALA    Serges              Math       #ERROR!     A+
# 2    3      NDJOKO                        Math     687051241     N-
# 3    4      NDONGO                      Dessin                   N-
# 4    5    ATANGANA                        Math       #ERROR!     A-
# 5    6    DJOUKENG                        Math       #ERROR!      A
# 6    7     DONFACK                        Math     655606907     A-
# 7    8      DOUNLA                        Math       #ERROR!      A
# 8    9  Dr. YONGUI                    Français                   Dr
# 9   10      FANKAM                        Math       #ERROR!     A-
# 10  11       ANABA                        Math       #ERROR!     A-
# 11  12      HUSKEN                        Math                   A-
# 12  13     MBONDJO            Culture Générale       #ERROR!     A-
# ...

# %%
"""-----BEGIN PRIVATE KEY-----

UP0lmJKvsEYawM2LgrX4hXXY
-----END PRIVATE KEY-----"""
